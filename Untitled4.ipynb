# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("/Users/tima/Downloads/dataset_telemetry.csv")
df['timestamp'] = pd.to_datetime(df['timestamp'])

# %%
snapshot_date = df['timestamp'].max() + pd.Timedelta(days=1)

recency = (
    df.groupby('userid')['timestamp']
      .max()
      .apply(lambda x: (snapshot_date - x).days)
      .rename('Recency')
)

# %%
significant_actions = ['category', 'search', 'product', 'cart', 'checkout', 'confirmation']

frequency = (
    df[df['action'].isin(significant_actions)]
    .groupby('userid')
    .size()
    .rename('Frequency')
)

# %%
# Частоты действий
action_freq = df['action'].value_counts(normalize=True)

# Глубина воронки
funnel_order = {
    'mainpage': 0,
    'category': 1,
    'search': 2,
    'product': 3,
    'cart': 4,
    'checkout': 5,
    'confirmation': 6
}

# Автоматические веса
weights = {}

for action in funnel_order:
    if action in action_freq:
        weights[action] = funnel_order[action] * (1 / action_freq[action])

weights = pd.Series(weights)

# Нормализация → минимальный вес = 1 (кроме mainpage)
weights = weights / weights[weights > 0].min()
weights = weights.round().astype(int)

weights['mainpage'] = 0  # жёстко

print(weights)
# Out:
# mainpage         0
# category         1
# search           2
# product          2
# cart             9
# checkout        42
# confirmation    99
# dtype: int64

# %%
df['m_score'] = df['action'].map(weights).fillna(0)

monetary = (
    df.groupby('userid')['m_score']
      .sum()
      .rename('Monetary')
)

# %%
rfm = pd.concat([recency, frequency, monetary], axis=1).fillna(0)
rfm.head()
# Out:
#             Recency  Frequency  Monetary
# userid
# user_10000        1       2572     13258
# user_10001        2       2679     13899
# user_10002        2       2484     11978
# user_10003        3       2615     13394
# user_10004        1       2678     13266

# %%
rfm['R_rank'] = pd.cut(
    rfm['Recency'],
    bins=[-1, 1, 3, 7, 14, 10**9],
    labels=[5, 4, 3, 2, 1]
).astype(int)

# %%
rfm['F_rank'] = pd.cut(
    rfm['Frequency'],
    bins=[-1, 1, 3, 5, 10, 10**9],
    labels=[1, 2, 3, 4, 5]
).astype(int)

# %%
rfm['M_rank'] = pd.cut(
    rfm['Monetary'],
    bins=[-1, 5, 15, 40, 100, 10**9],
    labels=[1, 2, 3, 4, 5]
).astype(int)

# %%
rfm['RFM_score'] = rfm[['R_rank', 'F_rank', 'M_rank']].sum(axis=1)

rfm['RFM_segment'] = (
    rfm['R_rank'].astype(str) +
    rfm['F_rank'].astype(str) +
    rfm['M_rank'].astype(str)
)

# %%
rfm[['Recency','Frequency','Monetary',
     'R_rank','F_rank','M_rank','RFM_score']].describe()

rfm[['R_rank','F_rank','M_rank']].value_counts().head(10)
# Out:
# R_rank  F_rank  M_rank
# 4       5       5         1203
# 5       5       5         1056
# 3       5       5          238
# 2       5       5            3
# Name: count, dtype: int64

# %%
rfm.head(10)
# Out:
#             Recency  Frequency  Monetary  R_rank  F_rank  M_rank  RFM_score  \
# userid
# user_10000        1       2572     13258       5       5       5         15
# user_10001        2       2679     13899       4       5       5         14
# user_10002        2       2484     11978       4       5       5         14
# user_10003        3       2615     13394       4       5       5         14
# user_10004        1       2678     13266       5       5       5         15
# user_10005        2       2691     13347       4       5       5         14
# user_10006        1       2808     14219       5       5       5         15
# user_10007        3       2744     13779       4       5       5         14
# user_10008        3       2784     13705       4       5       5         14
# user_10009        3       2720     12344       4       5       5         14
#
#            RFM_segment
# userid
# user_10000         555
# user_10001         455
# user_10002         455
# user_10003         455
# user_10004         555
# user_10005         455
# user_10006         555
# user_10007         455
# user_10008         455
# user_10009         455
